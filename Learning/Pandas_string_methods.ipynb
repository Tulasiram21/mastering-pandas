# %%
import pandas as pd

# %%
df=pd.read_csv('vgsales.csv')

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Find every game with the word "Mario" in its name

# %%
df[df['Name'].str.contains('Mario')]
# Out:
#         Rank                                               Name Platform  \
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 6          7                              New Super Mario Bros.       DS
# 8          9                          New Super Mario Bros. Wii      Wii
# 11        12                                      Mario Kart DS       DS
# ...      ...                                                ...      ...
# 12770  12772       Dance Dance Revolution: Mario Mix (JP sales)       GC
# 13273  13275               Detective Conan: Marionette Symphony      3DS
# 15261  15264                                       Mario Tennis      3DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year       Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Text to all lowercase or all uppercase using .str.lower() or .str.upper()

# %%
df['Genre']=df['Genre'].str.lower()

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df['Publisher']=df['Publisher'].str.upper()

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# # Find a specific substring and replace it with another one

# %%
df['Name']=df['Name'].str.replace('Mario','Super Mario')

# %%
df[df['Name'].str.contains('Super Mario')]
# Out:
#         Rank                                               Name Platform  \
# 1          2                            Super Super Mario Bros.      NES
# 2          3                               Super Mario Kart Wii      Wii
# 6          7                        New Super Super Mario Bros.       DS
# 8          9                    New Super Super Mario Bros. Wii      Wii
# 11        12                                Super Mario Kart DS       DS
# ...      ...                                                ...      ...
# 12770  12772  Dance Dance Revolution: Super Mario Mix (JP sa...       GC
# 13273  13275         Detective Conan: Super Marionette Symphony      3DS
# 15261  15264                                 Super Mario Tennis      3DS
# 16357  16360         Super Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16542  16545  Super Mario & Luigi: Paper Jam & Super Mario K...      3DS
#
#          Year       Genre           Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
