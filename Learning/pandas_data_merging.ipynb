# %%
import pandas as pd

# %%
df=pd.read_csv('vgsales.csv')

# %%
reviews_df={'Name':['Wii Sports','Super Mario Bros.','Mario Kart Wii','Wii Play','Pokémon Red/Blue','New Super Mario Bros. Wii','Wii Fit','Grand Theft Auto V','Pokémon Gold/Silver','Duck Hunt'],
            'User_Score':[8.0,8.5,8.3,6.8,9.0,8.4,8.0,8.2,9.0,7.9],
            'Critic_Score':[76,88,82,58,95,87,80,97,90,80]}

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
reviews_df=pd.DataFrame(reviews_df)
reviews_df
# Out:
#                         Name  User_Score  Critic_Score
# 0                 Wii Sports         8.0            76
# 1          Super Mario Bros.         8.5            88
# 2             Mario Kart Wii         8.3            82
# 3                   Wii Play         6.8            58
# 4           Pokémon Red/Blue         9.0            95
# 5  New Super Mario Bros. Wii         8.4            87
# 6                    Wii Fit         8.0            80
# 7         Grand Theft Auto V         8.2            97
# 8        Pokémon Gold/Silver         9.0            90
# 9                  Duck Hunt         7.9            80

# %%
df=pd.merge(df,reviews_df,on='Name')

# %%
df
# Out:
#     Rank                       Name Platform    Year     Genre  \
# 0      1                 Wii Sports      Wii  2006.0    Sports
# 1      2          Super Mario Bros.      NES  1985.0  Platform
# 2      3             Mario Kart Wii      Wii  2008.0    Racing
# 3      8                   Wii Play      Wii  2006.0      Misc
# 4      9  New Super Mario Bros. Wii      Wii  2009.0  Platform
# 5     10                  Duck Hunt      NES  1984.0   Shooter
# 6     14                    Wii Fit      Wii  2007.0    Sports
# 7     17         Grand Theft Auto V      PS3  2013.0    Action
# 8     24         Grand Theft Auto V     X360  2013.0    Action
# 9     45         Grand Theft Auto V      PS4  2014.0    Action
# 10   198         Grand Theft Auto V     XOne  2014.0    Action
# 11   201          Super Mario Bros.       GB  1999.0  Platform
# 12  1898         Grand Theft Auto V       PC  2015.0    Action
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...
